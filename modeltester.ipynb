# %%
from ultralytics import YOLO
import os

# Load a pre-trained YOLO model
model = YOLO('firstmodelv1.pt')


# Run batched inference on a list of images
results = model.predict("img1.jpg")  # return a list of Results objects
